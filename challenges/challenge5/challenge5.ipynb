# %% [markdown]
# # Challenge 5: Multi-Source, Multi-Agent
# ## Introduction
#
# In this part of the challenge you will add another source of data (structured) to the solution.
#
# <div class="alert alert-block alert-warning">
# Be Sure you populated correctly the `.env` file for the AZURE_SEARCH_INDEX.
# We are using <a href="https://pypi.org/project/python-dotenv/">python-dotenv</a> to manage our environment variables. It will also make things easier when deploying the application in Azure.
#
# </div>

# %% [markdown]
# ### Importing the libraries

# %%
from langchain_openai import AzureChatOpenAI
from langchain.agents import create_sql_agent
from langchain.agents.agent_toolkits import SQLDatabaseToolkit
from langchain_community.utilities import SQLDatabase
from langchain.prompts.chat import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from sqlalchemy import create_engine, text
from urllib.parse import quote_plus

# %% [markdown]
# ### Create Environment Variables
#
# **Important:** Make sure you update your `.env` file.

# %%
import os, dotenv,sys
dotenv.load_dotenv(override=True)

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '../../lib')))


# Setup environment
AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")
AZURE_OPENAI_MODEL = os.getenv("AZURE_OPENAI_MODEL")
AZURE_OPENAI_DEPLOYMENT_NAME = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME")
AZURE_OPENAI_EMBEDDING = os.getenv("AZURE_OPENAI_EMBEDDING")
# Azure Search
AZURE_SEARCH_ENDPOINT = os.getenv("AZURE_SEARCH_ENDPOINT")
AZURE_SEARCH_API_KEY = os.getenv("AZURE_SEARCH_API_KEY")
AZURE_SEARCH_INDEX = os.getenv("AZURE_SEARCH_INDEX")
AZURE_SEARCH_SERVICE = os.getenv("AZURE_SEARCH_SERVICE")
# Azure AI Document Intelligence
AZURE_DOCUMENT_INTELLIGENCE_ENDPOINT = os.getenv("AZURE_DOCUMENT_INTELLIGENCE_ENDPOINT")
AZURE_DOCUMENT_INTELLIGENCE_API_KEY = os.getenv("AZURE_DOCUMENT_INTELLIGENCE_API_KEY")
# Azure Blob Storage
AZURE_STORAGE_CONNECTION_STRING = os.getenv("AZURE_STORAGE_CONNECTION_STRING")
AZURE_STORAGE_CONTAINER = os.getenv("AZURE_STORAGE_CONTAINER")
AZURE_STORAGE_FOLDER = os.getenv("AZURE_STORAGE_FOLDER")
# SQL Database
SQL_SERVER = os.getenv("SQL_SERVER")
SQL_DB = os.getenv("SQL_DB")
SQL_USERNAME = os.getenv("SQL_USERNAME")
SQL_PWD = os.getenv("SQL_PWD")

# Define the questions list (if you are using your own dataset you need to change this list)
QUESTIONS = [
  "What are the revenues of GOOGLE in the year 2009?",
  "What are the revenues and the operative margins of ALPHABET Inc. in 2022 and how it compares with the previous year?",
  "Can you create a table with the total revenue for ALPHABET, NVIDIA, MICROSOFT and APPLE in year 2023?",
  "Can you give me the Fiscal Year 2023 Highlights for APPLE, MICROSOFT and NVIDIA?",
  "Did APPLE repurchase common stock in 2023? create a table of APPLE repurchased stock with date, numbers of stocks and values in dollars.",
  "What is the value of the cumulative 5-years total return of ALPHABET Class A at December 2022?",
  "What was the price of APPLE, NVIDIA and MICROSOFT stock in 23/07/2024?",
  "Can you buy 10 shares of APPLE for me?"
  ]

# Define the System prompt (you need to update this is you are using your own dataset.)
system_prompt_RAG = """ You are a financial assistant tasked with answering questions related to the financial results of major technology companies listed on NASDAQ, \n
specifically Microsoft (MSFT), Alphabet Inc. (GOOGL), Nvidia (NVDA), Apple Inc. (AAPL), and Amazon (AMZN). \n
if you don't find the answer in the context, just say `I don't know.`"""

system_prompt_START = """
  You are an agent that needs analyze the user question. \n
  Question : {input} \n
  if the question is related to stock prices answer with "stock". \n
  if the question is related to information about financial results answer with "rag". \n
  if the question is unclear or you cannot decide answer with "rag". \n
  only answer with one of the word provided.
  Your answer (stock/rag):
  """
system_prompt_SQL = """
  You are a helpful AI assistant expert in querying SQL Database to find answers to user's question about stock prices.
  If you can't find the answer, say 'I am unable to find the answer.'
  """

# %% [markdown]
# ## Step 1: Import data to the SQL Database
#
# The database provided is an Azure SQL Database.
# Upload the data to the SQL Database using the `./data/fsi/db/create_stock_table.sql` script.
#
# The script will create a table named "stock" in the provided database.
# The table contains the following columns:
# - **Date** DATE
# - **CloseLast** DECIMAL(10, 2)
# - **Volume** INT
# - **Open** DECIMAL(10, 2)
# - **High** DECIMAL(10, 2)
# - **Low** DECIMAL(10, 2)
# - **Symbol** VARCHAR(10)
#
# **NOTE**: Be sure that your IP address is not allowed to access the server.  To enable access, use the Azure Management Portal.
# It may take up to five minutes for this change to take effect
#
# <div class="alert alert-block alert-warning">
# After the Step will be completed, you don't need to run this anymore. it's a one time step as the SQL Table has been already populated.
# </div>

# %%
# Create the Connection to the SQL Server Database (sqlalchemy)
engine = create_engine(f"mssql+pymssql://{SQL_USERNAME}:{SQL_PWD}@{SQL_SERVER}:1433/{SQL_DB}")

# %%
# Create the Stock Table in the SQL Server Database
with open('../../data/fsi/db/create_stock_table.sql', 'r') as file:
    sql_statements = file.read()

# Execute the SQL Statements
with engine.connect() as connection:
    for command in sql_statements.split('GO\n'):
        command = command.strip()
        if command:
            connection.execute(text(command))
    connection.execute(text("commit"))

# %% [markdown]
# ## Step 2: Create a LangChain SQL Agent

# %%
# Create the Azure OpenAI Chat Client
llm = AzureChatOpenAI(
    azure_deployment=AZURE_OPENAI_DEPLOYMENT_NAME,
    api_key=AZURE_OPENAI_API_KEY,
    api_version=AZURE_OPENAI_API_VERSION,
    azure_endpoint=AZURE_OPENAI_ENDPOINT
)

# %%
# Create the LangChain SQL Database Object and the SQL Database Toolkit Object to be used by the agent.
# Create the Connection to the SQL Server Database (sqlalchemy)
engine = create_engine(f"mssql+pymssql://{SQL_USERNAME}:{SQL_PWD}@{SQL_SERVER}:1433/{SQL_DB}")

# %%
# Create the stock_agent using the Langhcain SQL Agent Class (create_sql_agent)
from langchain_community.utilities import SQLDatabase
from langchain.agents.agent_toolkits import SQLDatabaseToolkit

# Create the SQLDatabase object
db = SQLDatabase(engine)

# Create the SQLDatabaseToolkit object
toolkit = SQLDatabaseToolkit(db=db, llm=llm)

# Create the stock_agent using create_sql_agent
stock_agent = create_sql_agent(
    llm=llm,
    toolkit=toolkit,
    verbose=True
)

# %%
# Structure the final prompt from the ChatPromptTemplate
# Include the system message (provided at the biginning of the chapter - system_prompt_SQL) and the user message

from langchain.prompts.chat import ChatPromptTemplate

prompt_sql = ChatPromptTemplate.from_messages([
    ("system", system_prompt_SQL),
    ("human", "{question}")
])

# %%
# Test the agent
print(QUESTIONS[6])
response = stock_agent.invoke(prompt_sql.format(question=QUESTIONS[6]))
print(response['output'])
# Out:
# Can you buy 10 shares of APPLE for me?
#
#
# > Entering new SQL Agent Executor chain...
# ---------------------------------------------------------------------------
# OutputParserException                     Traceback (most recent call last)
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/agents/agent.py:1354, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1353     # Call the LLM to see what to do.
# -> 1354     output = self._action_agent.plan(
#    1355         intermediate_steps,
#    1356         callbacks=run_manager.get_child() if run_manager else None,
#    1357         **inputs,
#    1358     )
#    1359 except OutputParserException as e:
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/agents/agent.py:461, in RunnableAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     454 if self.stream_runnable:
#     455     # Use streaming to make sure that the underlying LLM is invoked in a
#     456     # streaming
#    (...)    459     # Because the response from the plan is not a generator, we need to
#     460     # accumulate the output into final output and return that.
# --> 461     for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     462         if final_output is None:
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3438, in RunnableSequence.stream(self, input, config, **kwargs)
#    3431 @override
#    3432 def stream(
#    3433     self,
#    (...)   3436     **kwargs: Optional[Any],
#    3437 ) -> Iterator[Output]:
# -> 3438     yield from self.transform(iter([input]), config, **kwargs)
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3424, in RunnableSequence.transform(self, input, config, **kwargs)
#    3417 @override
#    3418 def transform(
#    3419     self,
#    (...)   3422     **kwargs: Optional[Any],
#    3423 ) -> Iterator[Output]:
# -> 3424     yield from self._transform_stream_with_config(
#    3425         input,
#    3426         self._transform,
#    3427         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3428         **kwargs,
#    3429     )
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:2215, in Runnable._transform_stream_with_config(self, inputs, transformer, config, run_type, **kwargs)
#    2214 while True:
# -> 2215     chunk: Output = context.run(next, iterator)
#    2216     yield chunk
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3386, in RunnableSequence._transform(self, inputs, run_manager, config, **kwargs)
#    3384         final_pipeline = step.transform(final_pipeline, config)
# -> 3386 yield from final_pipeline
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:1447, in Runnable.transform(self, input, config, **kwargs)
#    1446 if got_first_val:
# -> 1447     yield from self.stream(final, config, **kwargs)
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:1014, in Runnable.stream(self, input, config, **kwargs)
#    1002 """Default implementation of stream, which calls invoke.
#    1003
#    1004 Subclasses should override this method if they support streaming output.
#    (...)   1012     The output of the Runnable.
#    1013 """
# -> 1014 yield self.invoke(input, config, **kwargs)
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:196, in BaseOutputParser.invoke(self, input, config, **kwargs)
#     195 if isinstance(input, BaseMessage):
# --> 196     return self._call_with_config(
#     197         lambda inner_input: self.parse_result(
#     198             [ChatGeneration(message=inner_input)]
#     199         ),
#     200         input,
#     201         config,
#     202         run_type="parser",
#     203     )
#     204 return self._call_with_config(
#     205     lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     206     input,
#     207     config,
#     208     run_type="parser",
#     209 )
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:1940, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    1937     with set_config_context(child_config) as context:
#    1938         output = cast(
#    1939             "Output",
# -> 1940             context.run(
#    1941                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1942                 func,
#    1943                 input_,
#    1944                 config,
#    1945                 run_manager,
#    1946                 **kwargs,
#    1947             ),
#    1948         )
#    1949 except BaseException as e:
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:197, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     195 if isinstance(input, BaseMessage):
#     196     return self._call_with_config(
# --> 197         lambda inner_input: self.parse_result(
#     198             [ChatGeneration(message=inner_input)]
#     199         ),
#     200         input,
#     201         config,
#     202         run_type="parser",
#     203     )
#     204 return self._call_with_config(
#     205     lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     206     input,
#     207     config,
#     208     run_type="parser",
#     209 )
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:250, in BaseOutputParser.parse_result(self, result, partial)
#     236 """Parse a list of candidate model Generations into a specific format.
#     237
#     238 The return value is parsed from only the first Generation in the result, which
#    (...)    248     Structured output.
#     249 """
# --> 250 return self.parse(result[0].text)
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/agents/output_parsers/react_single_input.py:75, in ReActSingleInputOutputParser.parse(self, text)
#      74 if not re.search(r"Action\s*\d*\s*:[\s]*(.*?)", text, re.DOTALL):
# ---> 75     raise OutputParserException(
#      76         f"Could not parse LLM output: `{text}`",
#      77         observation=MISSING_ACTION_AFTER_THOUGHT_ERROR_MESSAGE,
#      78         llm_output=text,
#      79         send_to_llm=True,
#      80     )
#      81 elif not re.search(
#      82     r"[\s]*Action\s*\d*\s*Input\s*\d*\s*:[\s]*(.*)", text, re.DOTALL
#      83 ):
#
# OutputParserException: Could not parse LLM output: `I cannot perform transactions such as buying shares. My role is only to query the database and provide you with information. If you have any questions regarding stock prices or related data, feel free to ask.`
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 3
#       1 # Test the agent
#       2 print(QUESTIONS[7])
# ----> 3 response = stock_agent.invoke(prompt_sql.format(question=QUESTIONS[7]))
#       4 print(response['output'])
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/chains/base.py:167, in Chain.invoke(self, input, config, **kwargs)
#     165 except BaseException as e:
#     166     run_manager.on_chain_error(e)
# --> 167     raise e
#     168 run_manager.on_chain_end(outputs)
#     170 if include_run_info:
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/chains/base.py:157, in Chain.invoke(self, input, config, **kwargs)
#     154 try:
#     155     self._validate_inputs(inputs)
#     156     outputs = (
# --> 157         self._call(inputs, run_manager=run_manager)
#     158         if new_arg_supported
#     159         else self._call(inputs)
#     160     )
#     162     final_outputs: dict[str, Any] = self.prep_outputs(
#     163         inputs, outputs, return_only_outputs
#     164     )
#     165 except BaseException as e:
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/agents/agent.py:1620, in AgentExecutor._call(self, inputs, run_manager)
#    1618 # We now enter the agent loop (until it returns something).
#    1619 while self._should_continue(iterations, time_elapsed):
# -> 1620     next_step_output = self._take_next_step(
#    1621         name_to_tool_map,
#    1622         color_mapping,
#    1623         inputs,
#    1624         intermediate_steps,
#    1625         run_manager=run_manager,
#    1626     )
#    1627     if isinstance(next_step_output, AgentFinish):
#    1628         return self._return(
#    1629             next_step_output, intermediate_steps, run_manager=run_manager
#    1630         )
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/agents/agent.py:1328, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1317 def _take_next_step(
#    1318     self,
#    1319     name_to_tool_map: dict[str, BaseTool],
#    (...)   1323     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1324 ) -> Union[AgentFinish, list[tuple[AgentAction, str]]]:
#    1325     return self._consume_next_step(
#    1326         [
#    1327             a
# -> 1328             for a in self._iter_next_step(
#    1329                 name_to_tool_map,
#    1330                 color_mapping,
#    1331                 inputs,
#    1332                 intermediate_steps,
#    1333                 run_manager,
#    1334             )
#    1335         ]
#    1336     )
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/agents/agent.py:1365, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1363     raise_error = False
#    1364 if raise_error:
# -> 1365     raise ValueError(
#    1366         "An output parsing error occurred. "
#    1367         "In order to pass this error back to the agent and have it try "
#    1368         "again, pass `handle_parsing_errors=True` to the AgentExecutor. "
#    1369         f"This is the error: {str(e)}"
#    1370     )
#    1371 text = str(e)
#    1372 if isinstance(self.handle_parsing_errors, bool):
#
# ValueError: An output parsing error occurred. In order to pass this error back to the agent and have it try again, pass `handle_parsing_errors=True` to the AgentExecutor. This is the error: Could not parse LLM output: `I cannot perform transactions such as buying shares. My role is only to query the database and provide you with information. If you have any questions regarding stock prices or related data, feel free to ask.`
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE

# %% [markdown]
# ## Step 3: Create the Multi Agent Solution

# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '../../lib')))

## Import the necessary libraries
from typing import Annotated, Sequence
from pydantic import BaseModel, Field
from typing_extensions import TypedDict
from langchain_core.messages import BaseMessage
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_core.prompts import PromptTemplate
from langchain_community.retrievers import AzureAISearchRetriever
from langchain_openai import AzureChatOpenAI
from langchain_core.messages import BaseMessage
from langgraph.graph.message import add_messages
from langgraph.prebuilt import tools_condition
from langgraph.graph import StateGraph, END
from its_a_rag import ingestion

# %%
# Create the Agent State Class to store the messages between the agents
# this should include the input, output and decision as strings
class AgentState(TypedDict):
    input: str
    output: str
    decision: str
    messages: Annotated[Sequence[BaseMessage], add_messages]

# %%
# Create the start_agent that analyze the user question and decide if the question is related to stock prices or financial results
def start_agent_node(state):
    # Import the LLM (you can use "global" to import the LLM in previous step to avoid re-creating the LLM objects)
    global llm, system_prompt_START

    # Prepare the prompt for the agent
    # Prompt Example: You are an agent that needs analyze the user question. \n Question : {input} \n if the question is related to stock prices answer with "stock". \n if the question is related to information about financial results answer with "rag". \n if the question is unclear or you cannot decide answer with "rag". \n only answer with one of the word provided. Your answer (stock/rag):

    from langchain.prompts import ChatPromptTemplate

    prompt = ChatPromptTemplate.from_messages([
        ("system", system_prompt_START),
        ("human", "{input}")
    ])

    # Prepare the chain to be executed
    formatted_prompt = prompt.format(input=state["input"])

    # invoke the chain
    response = llm.invoke(formatted_prompt)

    # take the decision from the response
    decision = response.content.strip().lower()
    if decision not in ["stock", "rag"]:
        decision = "rag"  # fallback to rag if unclear

    # Return the response for the next agent (decision and input required coming fron the Agent State)
    return {
        "input": state["input"],
        "decision": decision,
        "output": "",
        "messages": state.get("messages", [])
    }

# %%
## Stock Agent

def stock_agent_node(state):
    # Import the LLM (you can use "global" to import the LLM in previous step to avoid re-creating the LLM objects)
    global llm, db, toolkit, stock_agent, prompt_sql

    # Create the SQL Database Object and the SQL Database Toolkit Object to be used by the agent.
    # (Already created globally: db, toolkit, stock_agent)

    # Create the agent using the Langhcain SQL Agent Class (create_sql_agent)
    # (Already created globally: stock_agent)

    # Structure the final prompt from the ChatPromptTemplate
    question = state["input"]
    formatted_prompt = prompt_sql.format(question=question)

    # Prepare the response using the invoke method of the agent
    response = stock_agent.invoke(formatted_prompt)

    # Return the response for the next agent (output and input required coming fron the Agent State)
    return {
        "input": state["input"],
        "decision": state.get("decision", "stock"),
        "output": response['output'],
        "messages": state.get("messages", [])
    }

# %%
## Node rag (this is a clean implementation of the RAG Agent completed in Challenge 4)
def rag_agent_node(state):
    # Import the LLM (you can use "global" to import the LLM in previous step to avoid re-creating the LLM objects)
    global llm, system_prompt_RAG, AZURE_SEARCH_ENDPOINT, AZURE_SEARCH_API_KEY, AZURE_SEARCH_INDEX

    # Define the index (use the one created in the previous challenge)
    retriever = AzureAISearchRetriever(
        api_key=AZURE_SEARCH_API_KEY,
        service_name=AZURE_SEARCH_ENDPOINT,
        index_name=AZURE_SEARCH_INDEX,
        top_k=20
    )

    # Define the chain (as it was in the previous challenge)
    # Step 1: Retrieve relevant documents and extract image descriptions/texts
    def retrieve_and_describe(query):
        docs = retriever.get_relevant_documents(query)
        context = ingestion.get_image_description(docs)
        return {"context": context, "question": query}

    # Step 2: Generate the multimodal prompt
    def build_multimodal_prompt(inputs):
        return ingestion.multimodal_prompt(inputs)

    # Step 3: Build the Langchain chain
    chain_multimodal_rag = (
        RunnableLambda(retrieve_and_describe)  # Retrieve docs and extract context
        | RunnableLambda(build_multimodal_prompt)  # Build prompt with system, context, question
        | llm  # Azure OpenAI Chat client
        | StrOutputParser()  # Parse output
    )

    
    # prepare the response using the invoke method of the agent
    response = chain_multimodal_rag.invoke(state["input"])

    # Return the response for the next agent (output and input required coming from the Agent State)
    return {
        "input": state["input"],
        "decision": state.get("decision", "rag"),
        "output": response,
        "messages": state.get("messages", [])
    }

# %%
# Create the 3 steps graph that is going to be working in the bellow "decision" condition
# Add nodes (start_agent, stock_agent, rag_agent) and conditional edges where the decision with be stock or rag
def create_graph():
    # Create the Workflow as StateGraph using the AgentState
    workflow = StateGraph(AgentState)

    # Add the nodes (start_agent, stock_agent, rag_agent)
    workflow.add_node("start_agent", start_agent_node)
    workflow.add_node("stock_agent", stock_agent_node)
    workflow.add_node("rag_agent", rag_agent_node)

    # Add the conditional edge from start -> lambda (decision) -> stock_agent or rag_agent
    def route_decision(state):
        return state["decision"]

    workflow.add_conditional_edges(
        "start_agent",
        route_decision,
        {
            "stock": "stock_agent",
            "rag": "rag_agent"
        }
    )

    # Set the workflow entry point
    workflow.set_entry_point("start_agent")

    # Add the final edges to the END node
    workflow.add_edge("stock_agent", END)
    workflow.add_edge("rag_agent", END)

    # Compile and return the workflow
    return workflow.compile()

# %% [markdown]
# ### Step 4: Test the Solution

# %%
## Test Solution

# intantiate the graph (create_graph)
graph = create_graph()

# Use the graph invoke to answer the questions
# Test the graph with various questions

for QUESTION in QUESTIONS:
    print (QUESTION)
    result = graph.invoke({"input": QUESTION})
    print(result["output"])
    print ("------------------")
# Out:
# What are the revenues of GOOGLE in the year 2009?
# I don't know. The provided context does not include Google's revenues for the year 2009.
# ------------------
# What are the revenues and the operative margins of ALPHABET Inc. in 2022 and how it compares with the previous year?
# The provided context does not include specific information about Alphabet Inc.'s operating margins for 2022 or how they compare to the previous year. It does, however, include total revenues for 2022, which were $282,836 million, compared to $257,637 million in 2021, reflecting an increase of approximately 9.8%. For operating margins, the data is not available in the context provided.
# ------------------
# Can you create a table with the total revenue for ALPHABET, NVIDIA, MICROSOFT and APPLE in year 2023?
# Here is the table with the total revenue for Alphabet, NVIDIA, Microsoft, and Apple in 2023 based on the provided context:
#
# | **Company** | **2023 Revenue (in millions USD)** |
# |-------------|------------------------------------|
# | Alphabet    | Not provided in the context       |
# | NVIDIA      | $26,974                           |
# | Microsoft   | $211,915                          |
# | Apple       | $383,285                          |
#
# If you need Alphabet's revenue, it is not explicitly mentioned in the provided context.
# ------------------
# Can you give me the Fiscal Year 2023 Highlights for APPLE, MICROSOFT and NVIDIA?
# The context provided includes detailed information about NVIDIA, Apple, and Microsoft, but the fiscal year 2023 highlights for Apple, Microsoft, and NVIDIA are as follows:
#
# ### **Apple**
# - Total net sales: $383.3 billion, a 3% decrease compared to 2022.
# - Decline driven by lower Mac and iPhone sales, partially offset by higher Services revenue.
# - Product updates included: iPhone 15 series, Apple Watch Series 9, Apple Watch Ultra 2, MacBook Air 15", Mac Studio, Mac Pro, and Apple Vision Pro.
# - $76.6 billion in share repurchases and $15.0 billion in dividends paid.
#
# ### **Microsoft**
# - Revenue grew by 7%, driven by Intelligent Cloud and Productivity and Business Processes, offset by a decline in More Personal Computing.
# - Gross margin increased by 8%, with Microsoft Cloud gross margin percentage improving to 72%.
# - Operating income increased by 6%, driven by cloud growth and productivity services.
#
# ### **NVIDIA**
# - Total revenue for fiscal year 2023 (ending Jan 29, 2023): $26.97 billion.
# - Key growth areas included:
#   - **Data Center**: Revenue increased 217% year-over-year in fiscal year 2024 (compared to 2023 levels).
#   - **Gaming**: Revenue increased 15%, driven by new GPUs and technologies like DLSS 3.5.
#   - **Automotive**: Revenue grew by 21%, reflecting growth in self-driving platforms.
# - Net income for fiscal year 2023: $4.37 billion; gross margin: 56.9%.
#
# Let me know if you need further clarifications!
# ------------------
# Did APPLE repurchase common stock in 2023? create a table of APPLE repurchased stock with date, numbers of stocks and values in dollars.
#
#
# Yes, Apple repurchased common stock in 2023. Below is a table summarizing the repurchase details:
#
# | **Date/Period**               | **Number of Shares Repurchased (in millions)** | **Value (in billions USD)** | **Average Price Paid Per Share (USD)** |
# |-------------------------------|-----------------------------------------------|-----------------------------|---------------------------------------|
# | July 2, 2023 - August 5, 2023 | 33.864                                        | 6.49                        | 191.62                                |
# | August 6, 2023 - September 2, 2023 (ASRs) | 22.085 (1)                                   | 5.00                        | Volume-weighted average price (not finalized) |
# | August 6, 2023 - September 2, 2023 (Open Market) | 30.299                                   | 5.42                        | 178.99                                |
# | September 3, 2023 - September 30, 2023 | 20.347                                        | 3.59                        | 176.31                                |
# | **Total (2023)**              | 471 (2)                                       | 76.6                        | N/A                                   |
#
# **Notes:**
# 1. ASR (Accelerated Share Repurchase): Final share count and average price to be determined based on volume-weighted average price during the purchase period.
# 2. Total shares repurchased in 2023 were 471 million for $76.6 billion.
# ------------------
# What is the value of the cumulative 5-years total return of ALPHABET Class A at December 2022?
#
#
#
#
# The value of the cumulative 5-year total return for Alphabet Class A as of December 2022, based on the graph provided, is approximately **$200**.
# ------------------
# What was the price of APPLE, NVIDIA and MICROSOFT stock in 23/07/2024?
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""stockThe table "stock" seems relevant to the question. I should check its schema to understand the columns it contains and determine if it includes stock prices and dates for the requested companies: APPLE, NVIDIA, and MICROSOFT.
#
# Action: sql_db_schema
# Action Input: stock
# CREATE TABLE stock (
# 	[Date] DATE NULL,
# 	[CloseLast] DECIMAL(10, 2) NULL,
# 	[Volume] INTEGER NULL,
# 	[Open] DECIMAL(10, 2) NULL,
# 	[High] DECIMAL(10, 2) NULL,
# 	[Low] DECIMAL(10, 2) NULL,
# 	[Symbol] VARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL
# )
#
# /*
# 3 rows from stock table:
# Date	CloseLast	Volume	Open	High	Low	Symbol
# 2024-08-22	224.53	43695320	227.79	228.34	223.90	AAPL
# 2024-08-21	226.40	34765480	226.52	227.98	225.05	AAPL
# 2024-08-20	226.51	30299030	225.77	227.17	225.45	AAPL
# */The "stock" table contains stock prices with relevant columns such as "Date", "CloseLast" (closing price), and "Symbol" (stock symbol). To answer the question, I will query the "stock" table for the closing prices ("CloseLast") of APPLE (AAPL), NVIDIA (NVDA), and MICROSOFT (MSFT) on the specified date, 23/07/2024.
#
# Action: sql_db_query_checker
# Action Input: SELECT Symbol, CloseLast FROM stock WHERE Symbol IN ('AAPL', 'NVDA', 'MSFT') AND Date = '2024-07-23'```sql
# SELECT Symbol, CloseLast
# FROM stock
# WHERE Symbol IN ('AAPL', 'NVDA', 'MSFT')
#   AND Date = '2024-07-23';
# ```The query is correct and ready to execute.
#
# Action: sql_db_query
# Action Input: SELECT Symbol, CloseLast FROM stock WHERE Symbol IN ('AAPL', 'NVDA', 'MSFT') AND Date = '2024-07-23'[('AAPL', Decimal('225.01')), ('NVDA', Decimal('122.59')), ('MSFT', Decimal('444.85'))]Final Answer: On 23/07/2024, the closing prices for the stocks were as follows: APPLE (AAPL) - $225.01, NVIDIA (NVDA) - $122.59, and MICROSOFT (MSFT) - $444.85.
#
# > Finished chain.
# On 23/07/2024, the closing prices for the stocks were as follows: APPLE (AAPL) - $225.01, NVIDIA (NVDA) - $122.59, and MICROSOFT (MSFT) - $444.85.
# ------------------
# Can you buy 10 shares of APPLE for me?
#
#
# > Entering new SQL Agent Executor chain...
# ---------------------------------------------------------------------------
# OutputParserException                     Traceback (most recent call last)
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/agents/agent.py:1354, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1353     # Call the LLM to see what to do.
# -> 1354     output = self._action_agent.plan(
#    1355         intermediate_steps,
#    1356         callbacks=run_manager.get_child() if run_manager else None,
#    1357         **inputs,
#    1358     )
#    1359 except OutputParserException as e:
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/agents/agent.py:461, in RunnableAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     454 if self.stream_runnable:
#     455     # Use streaming to make sure that the underlying LLM is invoked in a
#     456     # streaming
#    (...)    459     # Because the response from the plan is not a generator, we need to
#     460     # accumulate the output into final output and return that.
# --> 461     for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     462         if final_output is None:
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3438, in RunnableSequence.stream(self, input, config, **kwargs)
#    3431 @override
#    3432 def stream(
#    3433     self,
#    (...)   3436     **kwargs: Optional[Any],
#    3437 ) -> Iterator[Output]:
# -> 3438     yield from self.transform(iter([input]), config, **kwargs)
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3424, in RunnableSequence.transform(self, input, config, **kwargs)
#    3417 @override
#    3418 def transform(
#    3419     self,
#    (...)   3422     **kwargs: Optional[Any],
#    3423 ) -> Iterator[Output]:
# -> 3424     yield from self._transform_stream_with_config(
#    3425         input,
#    3426         self._transform,
#    3427         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3428         **kwargs,
#    3429     )
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:2215, in Runnable._transform_stream_with_config(self, inputs, transformer, config, run_type, **kwargs)
#    2214 while True:
# -> 2215     chunk: Output = context.run(next, iterator)
#    2216     yield chunk
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3386, in RunnableSequence._transform(self, inputs, run_manager, config, **kwargs)
#    3384         final_pipeline = step.transform(final_pipeline, config)
# -> 3386 yield from final_pipeline
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:1447, in Runnable.transform(self, input, config, **kwargs)
#    1446 if got_first_val:
# -> 1447     yield from self.stream(final, config, **kwargs)
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:1014, in Runnable.stream(self, input, config, **kwargs)
#    1002 """Default implementation of stream, which calls invoke.
#    1003
#    1004 Subclasses should override this method if they support streaming output.
#    (...)   1012     The output of the Runnable.
#    1013 """
# -> 1014 yield self.invoke(input, config, **kwargs)
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:196, in BaseOutputParser.invoke(self, input, config, **kwargs)
#     195 if isinstance(input, BaseMessage):
# --> 196     return self._call_with_config(
#     197         lambda inner_input: self.parse_result(
#     198             [ChatGeneration(message=inner_input)]
#     199         ),
#     200         input,
#     201         config,
#     202         run_type="parser",
#     203     )
#     204 return self._call_with_config(
#     205     lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     206     input,
#     207     config,
#     208     run_type="parser",
#     209 )
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:1940, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    1937     with set_config_context(child_config) as context:
#    1938         output = cast(
#    1939             "Output",
# -> 1940             context.run(
#    1941                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1942                 func,
#    1943                 input_,
#    1944                 config,
#    1945                 run_manager,
#    1946                 **kwargs,
#    1947             ),
#    1948         )
#    1949 except BaseException as e:
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/runnables/config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:197, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     195 if isinstance(input, BaseMessage):
#     196     return self._call_with_config(
# --> 197         lambda inner_input: self.parse_result(
#     198             [ChatGeneration(message=inner_input)]
#     199         ),
#     200         input,
#     201         config,
#     202         run_type="parser",
#     203     )
#     204 return self._call_with_config(
#     205     lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     206     input,
#     207     config,
#     208     run_type="parser",
#     209 )
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:250, in BaseOutputParser.parse_result(self, result, partial)
#     236 """Parse a list of candidate model Generations into a specific format.
#     237
#     238 The return value is parsed from only the first Generation in the result, which
#    (...)    248     Structured output.
#     249 """
# --> 250 return self.parse(result[0].text)
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/agents/output_parsers/react_single_input.py:75, in ReActSingleInputOutputParser.parse(self, text)
#      74 if not re.search(r"Action\s*\d*\s*:[\s]*(.*?)", text, re.DOTALL):
# ---> 75     raise OutputParserException(
#      76         f"Could not parse LLM output: `{text}`",
#      77         observation=MISSING_ACTION_AFTER_THOUGHT_ERROR_MESSAGE,
#      78         llm_output=text,
#      79         send_to_llm=True,
#      80     )
#      81 elif not re.search(
#      82     r"[\s]*Action\s*\d*\s*Input\s*\d*\s*:[\s]*(.*)", text, re.DOTALL
#      83 ):
#
# OutputParserException: Could not parse LLM output: `I am unable to find the answer.`
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 11
#       9 for QUESTION in QUESTIONS:
#      10     print (QUESTION)
# ---> 11     result = graph.invoke({"input": QUESTION})
#      12     print(result["output"])
#      13     print ("------------------")
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:2336, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2334 else:
#    2335     chunks = []
# -> 2336 for chunk in self.stream(
#    2337     input,
#    2338     config,
#    2339     stream_mode=stream_mode,
#    2340     output_keys=output_keys,
#    2341     interrupt_before=interrupt_before,
#    2342     interrupt_after=interrupt_after,
#    2343     debug=debug,
#    2344     **kwargs,
#    2345 ):
#    2346     if stream_mode == "values":
#    2347         latest = chunk
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1993, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1987     # Similarly to Bulk Synchronous Parallel / Pregel model
#    1988     # computation proceeds in steps, while there are channel updates.
#    1989     # Channel updates from step N are only visible in step N+1
#    1990     # channels are guaranteed to be immutable for the duration of the step,
#    1991     # with channel updates applied only at the transition between steps.
#    1992     while loop.tick(input_keys=self.input_channels):
# -> 1993         for _ in runner.tick(
#    1994             loop.tasks.values(),
#    1995             timeout=self.step_timeout,
#    1996             retry_policy=self.retry_policy,
#    1997             get_waiter=get_waiter,
#    1998         ):
#    1999             # emit output
#    2000             yield from output()
#    2001 # emit output
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langgraph/pregel/runner.py:230, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     228 t = tasks[0]
#     229 try:
# --> 230     run_with_retry(
#     231         t,
#     232         retry_policy,
#     233         configurable={
#     234             CONFIG_KEY_SEND: partial(writer, t),
#     235             CONFIG_KEY_CALL: partial(call, t),
#     236         },
#     237     )
#     238     self.commit(t, None)
#     239 except Exception as exc:
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langgraph/pregel/retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langgraph/utils/runnable.py:546, in RunnableSeq.invoke(self, input, config, **kwargs)
#     542 config = patch_config(
#     543     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     544 )
#     545 if i == 0:
# --> 546     input = step.invoke(input, config, **kwargs)
#     547 else:
#     548     input = step.invoke(input, config)
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langgraph/utils/runnable.py:310, in RunnableCallable.invoke(self, input, config, **kwargs)
#     308 else:
#     309     context.run(_set_config_context, config)
# --> 310     ret = context.run(self.func, *args, **kwargs)
#     311 if isinstance(ret, Runnable) and self.recurse:
#     312     return ret.invoke(input, config)
#
# Cell In[75], line 18, in stock_agent_node(state)
#      15 formatted_prompt = prompt_sql.format(question=question)
#      17 # Prepare the response using the invoke method of the agent
# ---> 18 response = stock_agent.invoke(formatted_prompt)
#      20 # Return the response for the next agent (output and input required coming fron the Agent State)
#      21 return {
#      22     "input": state["input"],
#      23     "decision": state.get("decision", "stock"),
#      24     "output": response['output'],
#      25     "messages": state.get("messages", [])
#      26 }
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/chains/base.py:167, in Chain.invoke(self, input, config, **kwargs)
#     165 except BaseException as e:
#     166     run_manager.on_chain_error(e)
# --> 167     raise e
#     168 run_manager.on_chain_end(outputs)
#     170 if include_run_info:
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/chains/base.py:157, in Chain.invoke(self, input, config, **kwargs)
#     154 try:
#     155     self._validate_inputs(inputs)
#     156     outputs = (
# --> 157         self._call(inputs, run_manager=run_manager)
#     158         if new_arg_supported
#     159         else self._call(inputs)
#     160     )
#     162     final_outputs: dict[str, Any] = self.prep_outputs(
#     163         inputs, outputs, return_only_outputs
#     164     )
#     165 except BaseException as e:
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/agents/agent.py:1620, in AgentExecutor._call(self, inputs, run_manager)
#    1618 # We now enter the agent loop (until it returns something).
#    1619 while self._should_continue(iterations, time_elapsed):
# -> 1620     next_step_output = self._take_next_step(
#    1621         name_to_tool_map,
#    1622         color_mapping,
#    1623         inputs,
#    1624         intermediate_steps,
#    1625         run_manager=run_manager,
#    1626     )
#    1627     if isinstance(next_step_output, AgentFinish):
#    1628         return self._return(
#    1629             next_step_output, intermediate_steps, run_manager=run_manager
#    1630         )
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/agents/agent.py:1328, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1317 def _take_next_step(
#    1318     self,
#    1319     name_to_tool_map: dict[str, BaseTool],
#    (...)   1323     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1324 ) -> Union[AgentFinish, list[tuple[AgentAction, str]]]:
#    1325     return self._consume_next_step(
#    1326         [
#    1327             a
# -> 1328             for a in self._iter_next_step(
#    1329                 name_to_tool_map,
#    1330                 color_mapping,
#    1331                 inputs,
#    1332                 intermediate_steps,
#    1333                 run_manager,
#    1334             )
#    1335         ]
#    1336     )
#
# File /workspaces/itsarag/.venv/lib/python3.12/site-packages/langchain/agents/agent.py:1365, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1363     raise_error = False
#    1364 if raise_error:
# -> 1365     raise ValueError(
#    1366         "An output parsing error occurred. "
#    1367         "In order to pass this error back to the agent and have it try "
#    1368         "again, pass `handle_parsing_errors=True` to the AgentExecutor. "
#    1369         f"This is the error: {str(e)}"
#    1370     )
#    1371 text = str(e)
#    1372 if isinstance(self.handle_parsing_errors, bool):
#
# ValueError: An output parsing error occurred. In order to pass this error back to the agent and have it try again, pass `handle_parsing_errors=True` to the AgentExecutor. This is the error: Could not parse LLM output: `I am unable to find the answer.`
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# During task with name 'stock_agent' and id '37e5c2f8-85cb-46f3-e58a-c0eaca083cf5'
